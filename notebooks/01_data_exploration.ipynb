# %% [markdown]
# # 01 — Data Exploration
#
# **Reference:** `implementation_plan.md` → Section 5 (Dataset Strategy), Section 8.1 (Data Bugs)
#
# **Purpose of this notebook:**
# - Browse the INCLUDE dataset structure and verify video counts per word.
# - Visualize sample keypoint frames and landmark coordinate distributions.
# - Identify class imbalance and determine which words need supplementary data (CISLR/Kaggle).
# - Confirm that `vocabulary.json` word list matches available INCLUDE categories.
#
# **Runs on:** Day 1 (Task 1.7) after INCLUDE download completes.
#
# ---
#
# ## Section 1: Dataset Directory Inspection
# <!-- Zest: os.listdir(INCLUDE_DIR) -> count subdirs -> count .mp4 per subdir -> DataFrame -->
#
# ## Section 2: Sample Video Keypoint Visualization
# <!-- Zest: Pick 3 words -> run extract_keypoints on one sample each -> plot x,y coords per frame -->
#
# ## Section 3: Class Balance Analysis
# <!-- Zest: Plot bar chart of video counts per class -> flag classes < 8 samples -->
#
# ## Section 4: Vocabulary Coverage Check
# <!-- Zest: Load vocabulary.json -> check each word exists in INCLUDE dirs -> print missing words -->
